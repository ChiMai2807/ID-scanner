# %%
import cv2
import os
from glob import glob

def crop_from_labels(
    image_dir: str,
    label_dir: str,
    output_dir: str
):
    os.makedirs(output_dir, exist_ok=True)

    for lbl_path in glob(os.path.join(label_dir, "*.txt")):
        base = os.path.splitext(os.path.basename(lbl_path))[0]
        img_path = os.path.join(image_dir, base + ".jpg")
        img = cv2.imread(img_path)
        h, w = img.shape[:2]

        with open(lbl_path) as f:
            for i, line in enumerate(f):
                cls_id, x_ctr, y_ctr, w_rel, h_rel = map(float, line.split())
                # convert normalized to pixels
                bw, bh = w_rel * w, h_rel * h
                bx, by = x_ctr * w, y_ctr * h
                x1 = int(bx - bw/2)
                y1 = int(by - bh/2)
                x2 = int(bx + bw/2)
                y2 = int(by + bh/2)

                crop = img[y1:y2, x1:x2]
                out_name = f"{base}_cls{int(cls_id)}_{i}.jpg"
                cv2.imwrite(os.path.join(output_dir, out_name), crop)

if __name__ == "__main__":
    crop_from_labels(
        image_dir="cccd_id.v3i.yolov8/train/images",
        label_dir="cccd_id.v3i.yolov8/train/labels",
        output_dir="cropped_id_train_1"
    )

# %%
import os
import re

def clean_filenames(folder: str):
    # matches the unwanted hash‐style suffix
    pattern = re.compile(r'_(?:jpg|png)\.rf\.[0-9a-fA-F]+')
    
    for fname in os.listdir(folder):
        full_path = os.path.join(folder, fname)
        if not os.path.isfile(full_path):
            continue

        base, ext = os.path.splitext(fname)
        # remove the _jpg.rf.<hash> or _png.rf.<hash> part
        new_base = pattern.sub('', base)
        
        # if something changed, rename
        if new_base != base:
            new_name = new_base + ext
            new_path = os.path.join(folder, new_name)
            print(f"Renaming:\n  {fname}\n→ {new_name}\n")
            os.rename(full_path, new_path)

if __name__ == "__main__":
    clean_filenames("cropped_id_train_1")
# Out:
# Renaming:
#   img1357_jpg.rf.6f3505524a484948e971ab021e874b96_cls0_0.jpg
# → img1357_cls0_0.jpg
#
# Renaming:
#   img1488_jpg.rf.5ef434631313b73c3f5292ce136534f2_cls0_0.jpg
# → img1488_cls0_0.jpg
#
# Renaming:
#   img1339_jpg.rf.d959c04539fca4fa511168bf10d856a2_cls0_0.jpg
# → img1339_cls0_0.jpg
#
# Renaming:
#   img1275_jpg.rf.8b0f0725bad1401cbc4219d34dfc1092_cls0_0.jpg
# → img1275_cls0_0.jpg
#
# Renaming:
#   img1038_jpg.rf.34531171c7e9b2dbe1241509690bbd0f_cls0_0.jpg
# → img1038_cls0_0.jpg
#
# Renaming:
#   img1627_jpg.rf.42633b7fa32a824c35877d9f5c8e3a31_cls0_0.jpg
# → img1627_cls0_0.jpg
#
# Renaming:
#   img1316_jpg.rf.f9e58d36213333fc16279f09ad994a8c_cls0_0.jpg
# → img1316_cls0_0.jpg
#
# Renaming:
#   img1280_jpg.rf.81331000d1b7bc215bbf45a21c430da0_cls0_0.jpg
# → img1280_cls0_0.jpg
#
# Renaming:
#   img1303_jpg.rf.13b75e847c9f0228f712c661cb87b33c_cls0_0.jpg
# → img1303_cls0_0.jpg
#
# Renaming:
#   img1617_jpg.rf.6c96651ccdec0a4aeb7e26043a1894be_cls0_0.jpg
# → img1617_cls0_0.jpg
#
# Renaming:
#   img1564_jpg.rf.8fde99098bc5e959ef0035e4cfeae211_cls0_0.jpg
# → img1564_cls0_0.jpg
#
# Renaming:
#   img1287_jpg.rf.4ab1ce0ac6c2d4bbdf8cdc380522427c_cls0_0.jpg
# → img1287_cls0_0.jpg
#
# Renaming:
#   img1620_jpg.rf.f097cf0948cd4058e92171050e15d06e_cls0_0.jpg
# → img1620_cls0_0.jpg
#
# Renaming:
#   img1297_jpg.rf.f30aeabe159b87642ee14273a5145c93_cls0_0.jpg
# → img1297_cls0_0.jpg
#
# Renaming:
#   img1629_jpg.rf.f776a8c65fc76d663d0e946425ae2f3e_cls0_0.jpg
# → img1629_cls0_0.jpg
#
# Renaming:
#   img1359_jpg.rf.4bd98ecda3566a9e913cba4aecd78aa7_cls0_0.jpg
# → img1359_cls0_0.jpg
#
# Renaming:
#   img1283_jpg.rf.ac5b00e762471b33d160bb7b8d3d3bfa_cls0_0.jpg
# → img1283_cls0_0.jpg
#
# Renaming:
#   img1363_jpg.rf.4098a9653e5afa29169998618295e050_cls0_0.jpg
# → img1363_cls0_0.jpg
#
# Renaming:
#   img1589_jpg.rf.fc8b792914dbce2d46345ca47e1a756d_cls0_0.jpg
# → img1589_cls0_0.jpg
#
# Renaming:
#   img1302_jpg.rf.77287d47afba9be54d1ab34f1a2e2e8b_cls0_0.jpg
# → img1302_cls0_0.jpg
#
# Renaming:
#   img1381_jpg.rf.aa20e6827b688e3ae9e4da12808d01c0_cls0_0.jpg
# → img1381_cls0_0.jpg
#
# Renaming:
#   img1587_jpg.rf.f05a113da985e969f482e1390f6c1600_cls0_0.jpg
# → img1587_cls0_0.jpg
#
# Renaming:
#   img1491_jpg.rf.925d26b6f29e267dd3df1546c11f7fca_cls0_0.jpg
# → img1491_cls0_0.jpg
#
# Renaming:
#   img973_jpg.rf.9a38c5a2bc0b9e244049955d8f446e45_cls0_0.jpg
# → img973_cls0_0.jpg
#
# Renaming:
#   img1548_jpg.rf.d52b6900d3569eff29e17c440a76879c_cls0_0.jpg
# → img1548_cls0_0.jpg
#
# Renaming:
#   img1478_jpg.rf.80d67ace80569e5d3677a3b9cf658de0_cls0_0.jpg
# → img1478_cls0_0.jpg
#
# Renaming:
#   img1075_jpg.rf.2839e43e4019dfff2be7791d02c31de4_cls0_0.jpg
# → img1075_cls0_0.jpg
#
# Renaming:
#   img1233_jpg.rf.250d27779a25b138211cac8fd1627f2f_cls0_0.jpg
# → img1233_cls0_0.jpg
#
# Renaming:
#   img1310_jpg.rf.8e0fc05ed7905b155778d101dfa7aad9_cls0_0.jpg
# → img1310_cls0_0.jpg
#
# Renaming:
#   img1545_jpg.rf.1c5dfb829b37ee1542b4b039b83ec8ca_cls0_0.jpg
# → img1545_cls0_0.jpg
#
# Renaming:
#   img1321_jpg.rf.71908139cc549bf02bc739efda1197bf_cls0_0.jpg
# → img1321_cls0_0.jpg
#
# Renaming:
#   img1329_jpg.rf.db332b13e57fe0d0c22bac27ca4aab65_cls0_0.jpg
# → img1329_cls0_0.jpg
#
# Renaming:
#   img1448_jpg.rf.1fab914d06fbb6badab99e6778097fe2_cls0_0.jpg
# → img1448_cls0_0.jpg
#
# Renaming:
#   img1336_jpg.rf.7372095c583b766694456c2d57285e40_cls0_0.jpg
# → img1336_cls0_0.jpg
#
# Renaming:
#   img1431_jpg.rf.e57cf3c4dfc7a9b7e4219c86378bdae1_cls0_0.jpg
# → img1431_cls0_0.jpg
#
# Renaming:
#   img1361_jpg.rf.7457c155945ce6d7c1dd8a90fb7c5f27_cls0_0.jpg
# → img1361_cls0_0.jpg
#
# Renaming:
#   img1512_jpg.rf.7f69e7ff06fdfd8c1743cc1fba235cea_cls0_0.jpg
# → img1512_cls0_0.jpg
#
# Renaming:
#   img1567_jpg.rf.10182ee8905e6fab4e04c2c65c78299b_cls0_0.jpg
# → img1567_cls0_0.jpg
#
# Renaming:
#   img1318_jpg.rf.6fe8d2cd515ccb97bd07facb0c7c14a4_cls0_0.jpg
# → img1318_cls0_0.jpg
#
# Renaming:
#   img1610_jpg.rf.c08bdc25f791353f2426a4d71895a8a7_cls0_0.jpg
# → img1610_cls0_0.jpg
#
# Renaming:
#   img1603_jpg.rf.ae6f8ea0e720ee3347e0faa51990a851_cls0_0.jpg
# → img1603_cls0_0.jpg
#
# Renaming:
#   img1485_jpg.rf.084eaa8f84d98e3508e18cf5db4f87d9_cls0_0.jpg
# → img1485_cls0_0.jpg
#
# Renaming:
#   img1537_jpg.rf.3e96f57684174f7624cee7879e3fc4f0_cls0_0.jpg
# → img1537_cls0_0.jpg
#
# Renaming:
#   img1325_jpg.rf.53b06a74c2d54d16b02f54ecbc2ed70a_cls0_0.jpg
# → img1325_cls0_0.jpg
#
# Renaming:
#   img1366_jpg.rf.b561417f2efbe7af9a700aa889dbaa8d_cls0_0.jpg
# → img1366_cls0_0.jpg
#
# Renaming:
#   img1605_jpg.rf.ef25f5742ca9eb262ff85737cf79b24f_cls0_0.jpg
# → img1605_cls0_0.jpg
#
# Renaming:
#   img1309_jpg.rf.f025b3ac460005e6999a0d72aad1e106_cls0_0.jpg
# → img1309_cls0_0.jpg
#
# Renaming:
#   img1581_jpg.rf.4d56eeec2d6fbc947867485363c6bd24_cls0_0.jpg
# → img1581_cls0_0.jpg
#
# Renaming:
#   img1349_jpg.rf.e6ab6296f98c39826102b56bcd15134f_cls0_0.jpg
# → img1349_cls0_0.jpg
#
# Renaming:
#   img1441_jpg.rf.cdb98be393c91abf8f09472a63c45bed_cls0_0.jpg
# → img1441_cls0_0.jpg
#
# Renaming:
#   img1271_jpg.rf.c4a777b3ac321fd2ca0e1b860583cf6f_cls0_0.jpg
# → img1271_cls0_0.jpg
#
# Renaming:
#   img1317_jpg.rf.ad83dd387b3790e504a7cfcd6ce06b29_cls0_0.jpg
# → img1317_cls0_0.jpg
#
# Renaming:
#   img1560_jpg.rf.551959d88b1ef9941f48bc3707b4c831_cls0_0.jpg
# → img1560_cls0_0.jpg
#
# Renaming:
#   img1171_jpg.rf.1499e94aefd840ee1b11ef06be0692cf_cls0_0.jpg
# → img1171_cls0_0.jpg
#
# Renaming:
#   img1282_jpg.rf.a1e1ac50c8f1aeaf61caa7aed8b4dfd5_cls0_0.jpg
# → img1282_cls0_0.jpg
#
# Renaming:
#   img1402_jpg.rf.de3aea3b25ea584a616044f8f185bd52_cls0_0.jpg
# → img1402_cls0_0.jpg
#
# Renaming:
#   img1270_jpg.rf.617c79c7ba8f2270808ade5c3204c6ae_cls0_0.jpg
# → img1270_cls0_0.jpg
#
# Renaming:
#   img1430_jpg.rf.5896ce33739ddc062d5757a560c92be6_cls0_0.jpg
# → img1430_cls0_0.jpg
#
# Renaming:
#   img1277_jpg.rf.b11de1ed56c7e231120a9de2df466493_cls0_0.jpg
# → img1277_cls0_0.jpg
#
# Renaming:
#   img1292_jpg.rf.c2d4e0713cc46295fd4bfc98a22ee72a_cls0_0.jpg
# → img1292_cls0_0.jpg
#
# Renaming:
#   img1434_jpg.rf.4dd54303ea468ea4ab65b462d2dd8e7d_cls0_0.jpg
# → img1434_cls0_0.jpg
#
# Renaming:
#   img1447_jpg.rf.74d9ef9167d7d352126a63449e188647_cls0_0.jpg
# → img1447_cls0_0.jpg
#
# Renaming:
#   img1408_jpg.rf.3d1c22bd065403a843911e7e606128b6_cls0_0.jpg
# → img1408_cls0_0.jpg
#
# Renaming:
#   img1337_jpg.rf.ff03f4622b030a06f159c3db65828ccc_cls0_0.jpg
# → img1337_cls0_0.jpg
#
# Renaming:
#   img1425_jpg.rf.57ede2dec5713e8a7113c9f42a38ca79_cls0_0.jpg
# → img1425_cls0_0.jpg
#
# Renaming:
#   img1036_jpg.rf.226a9b4e1654a6980c54fb686398172b_cls0_0.jpg
# → img1036_cls0_0.jpg
#
# Renaming:
#   img1308_jpg.rf.63c065ec1c92bc67263cc62f84eecf04_cls0_0.jpg
# → img1308_cls0_0.jpg
#
# Renaming:
#   img1435_jpg.rf.bae50d650d0c2ab60a7e89e45043689a_cls0_0.jpg
# → img1435_cls0_0.jpg
#
# Renaming:
#   img1608_jpg.rf.a8cf6a809e68279607b5edf6a037baf4_cls0_0.jpg
# → img1608_cls0_0.jpg
#
# Renaming:
#   img1362_jpg.rf.b5d4ca58da89d642c4b86aaa3690ec82_cls0_0.jpg
# → img1362_cls0_0.jpg
#
# Renaming:
#   img1360_jpg.rf.66c7563537ccf38f0c60f37bf206428b_cls0_0.jpg
# → img1360_cls0_0.jpg
#
# Renaming:
#   img1552_jpg.rf.5ebef3bfbe454674530e05ccd84fc1b0_cls0_0.jpg
# → img1552_cls0_0.jpg
#
# Renaming:
#   img1554_jpg.rf.65af992b5e8d06a16c90af5d58747bf9_cls0_0.jpg
# → img1554_cls0_0.jpg
#
# Renaming:
#   img1377_jpg.rf.c8b14709206e2a0528cff944f7ea6ae1_cls0_0.jpg
# → img1377_cls0_0.jpg
#
# Renaming:
#   img1331_jpg.rf.fe8e6ca89ef160d8a65a0b1073951640_cls0_0.jpg
# → img1331_cls0_0.jpg
#
# Renaming:
#   img1445_jpg.rf.1498572d7892d3481dd15879c23b3eff_cls0_0.jpg
# → img1445_cls0_0.jpg
#
# Renaming:
#   img1324_jpg.rf.89b6a458dedf48c3a1cd5e044a7aa505_cls0_0.jpg
# → img1324_cls0_0.jpg
#
# Renaming:
#   img1526_jpg.rf.90bd39e2cbdb7eb17a764118cb0cb25e_cls0_0.jpg
# → img1526_cls0_0.jpg
#
# Renaming:
#   img1290_jpg.rf.c700deab1b0dffb13916af4a6e85b022_cls0_0.jpg
# → img1290_cls0_0.jpg
#
# Renaming:
#   img1269_jpg.rf.c07ad36bc1f34ac706f79649a2a72d9a_cls0_0.jpg
# → img1269_cls0_0.jpg
#
# Renaming:
#   img1350_jpg.rf.f3fd95e70e7771350be35fb90164cbd2_cls0_0.jpg
# → img1350_cls0_0.jpg
#
# Renaming:
#   img1322_jpg.rf.2fb83fb0628141ddfc5ef23f82dd0f2a_cls0_0.jpg
# → img1322_cls0_0.jpg
#
# Renaming:
#   img1427_jpg.rf.2101555c319cff86806776728b8918d6_cls0_0.jpg
# → img1427_cls0_0.jpg
#
# Renaming:
#   img1330_jpg.rf.46a548176d2b8f3e4036216db800c9cd_cls0_0.jpg
# → img1330_cls0_0.jpg
#
# Renaming:
#   img1440_jpg.rf.3d4277e69cbeac17dc98f23d5ef40ab7_cls0_0.jpg
# → img1440_cls0_0.jpg
#
# Renaming:
#   img1371_jpg.rf.008c76d5b58f1c67373a48546d72b7e0_cls0_0.jpg
# → img1371_cls0_0.jpg
#
# Renaming:
#   img1438_jpg.rf.73ece0069ec4d665df427a12bab6bb83_cls0_0.jpg
# → img1438_cls0_0.jpg
#
# Renaming:
#   img1601_jpg.rf.aecce5e696665f534fd87688de0e8aca_cls0_0.jpg
# → img1601_cls0_0.jpg
#
# Renaming:
#   img1344_jpg.rf.c6d5627871f82777766bab8c29d58481_cls0_0.jpg
# → img1344_cls0_0.jpg
#
# Renaming:
#   img1346_jpg.rf.f2422831e8c65a7d9d95557d7871eb83_cls0_0.jpg
# → img1346_cls0_0.jpg
#
# Renaming:
#   img1439_jpg.rf.814ab7cfd0c27712783d890d0fe7c681_cls0_0.jpg
# → img1439_cls0_0.jpg
#
# Renaming:
#   img1328_jpg.rf.d1aa891d1f7141846b59ea6b8292460b_cls0_0.jpg
# → img1328_cls0_0.jpg
#
# Renaming:
#   img1528_jpg.rf.3907deb342c3842964a6fbe4c58a4e47_cls0_0.jpg
# → img1528_cls0_0.jpg
#
# Renaming:
#   img1334_jpg.rf.b1dfb2d549c9c26f2020349027d4e322_cls0_0.jpg
# → img1334_cls0_0.jpg
#
# Renaming:
#   img1235_jpg.rf.b352f302e02d80ad2c916fc103700fff_cls0_0.jpg
# → img1235_cls0_0.jpg
#
# Renaming:
#   img1348_jpg.rf.a551ed574af40dfab7d494458bbc1825_cls0_0.jpg
# → img1348_cls0_0.jpg
#
# Renaming:
#   img1342_jpg.rf.b7e781bd34e4ab83a58617125bc80736_cls0_0.jpg
# → img1342_cls0_0.jpg
#
# Renaming:
#   img1590_jpg.rf.b31694c3619052efb69cce7604817bbb_cls0_0.jpg
# → img1590_cls0_0.jpg
#
# Renaming:
#   img1532_jpg.rf.195201a07f6f5f8c77b707be8c7ef959_cls0_0.jpg
# → img1532_cls0_0.jpg
#
# Renaming:
#   img1404_jpg.rf.aa339f538fd6aac2a874af730974f8d6_cls0_0.jpg
# → img1404_cls0_0.jpg
#
# Renaming:
#   img1573_jpg.rf.06262c349653ad4f93cee6358df435c5_cls0_0.jpg
# → img1573_cls0_0.jpg
#
# Renaming:
#   img1268_jpg.rf.0105131a6b2ded7dfa4d5b951562fe86_cls0_0.jpg
# → img1268_cls0_0.jpg
#
# Renaming:
#   img1443_jpg.rf.2ee49214b9d4ae48adc77d66bf3b8d11_cls0_0.jpg
# → img1443_cls0_0.jpg
#
# Renaming:
#   img1405_jpg.rf.7216948f1b1a01e6544220766c3c0c16_cls0_0.jpg
# → img1405_cls0_0.jpg
#
# Renaming:
#   img1353_jpg.rf.1a11d956224b820791099dd6e17ee158_cls0_0.jpg
# → img1353_cls0_0.jpg
#
# Renaming:
#   img1323_jpg.rf.7b5eaf1b647eb45d4e8f01f80663c4dc_cls0_0.jpg
# → img1323_cls0_0.jpg
#
# Renaming:
#   img1437_jpg.rf.447774ae1eb031970cd349dc7d088742_cls0_0.jpg
# → img1437_cls0_0.jpg
#
# Renaming:
#   img1561_jpg.rf.8becf2447874f980f7702e7a9ff0229f_cls0_0.jpg
# → img1561_cls0_0.jpg
#
# Renaming:
#   img1300_jpg.rf.1c1fdccafcd37bcef1ac15bb5504a9f3_cls0_0.jpg
# → img1300_cls0_0.jpg
#
# Renaming:
#   img1453_jpg.rf.e19701b7a12730aaae6c040174238c6b_cls0_0.jpg
# → img1453_cls0_0.jpg
#
# Renaming:
#   img1347_jpg.rf.61e0b8f6fc553b4c0a70b607800b1e63_cls0_0.jpg
# → img1347_cls0_0.jpg
#
# Renaming:
#   img1314_jpg.rf.af9466e3d8f09785aaaff4397f1efb06_cls0_0.jpg
# → img1314_cls0_0.jpg
#
# Renaming:
#   img1539_jpg.rf.e6bde00abf7c53f447446245f5d4cd14_cls0_0.jpg
# → img1539_cls0_0.jpg
#
# Renaming:
#   img1278_jpg.rf.db6bf509a27bb906ccf79498e0c33377_cls0_0.jpg
# → img1278_cls0_0.jpg
#
# Renaming:
#   img1424_jpg.rf.708f1057b50073866a282b5d04e7c0cf_cls0_0.jpg
# → img1424_cls0_0.jpg
#
# Renaming:
#   img1451_jpg.rf.4ee7567603350be886b96440078d66a7_cls0_0.jpg
# → img1451_cls0_0.jpg
#
# Renaming:
#   img1351_jpg.rf.b651f5c4dbe565d592c7745bd482894d_cls0_0.jpg
# → img1351_cls0_0.jpg
#
# Renaming:
#   img1614_jpg.rf.5f2d37a44dee5b254ccac5d11779b75d_cls0_0.jpg
# → img1614_cls0_0.jpg
#
# Renaming:
#   img1326_jpg.rf.71d263491ac2d795327237f78e30b15e_cls0_0.jpg
# → img1326_cls0_0.jpg
#
# Renaming:
#   img1432_jpg.rf.5f8a90f87353bbc3767eee63964941da_cls0_0.jpg
# → img1432_cls0_0.jpg
#
# Renaming:
#   img1578_jpg.rf.3af04815e6d9e7fbe8ca3c52e9adb15b_cls0_0.jpg
# → img1578_cls0_0.jpg
#
# Renaming:
#   img1306_jpg.rf.2fe1a1e19e2b970d05218cc07ecbf3b9_cls0_0.jpg
# → img1306_cls0_0.jpg
#
# Renaming:
#   img1035_jpg.rf.2f6136233d42e25a47e5789504a799bf_cls0_0.jpg
# → img1035_cls0_0.jpg
#
# Renaming:
#   img1593_jpg.rf.5ab541342cf6e7f89bd6fc8f06c73f2d_cls0_0.jpg
# → img1593_cls0_0.jpg
#
# Renaming:
#   img1313_jpg.rf.1a757f2c4a528bfbe2e91dea5b8340e6_cls0_0.jpg
# → img1313_cls0_0.jpg
#
# Renaming:
#   img1286_jpg.rf.17d5a1ce15229a6d7e6215ae1b6a32cd_cls0_0.jpg
# → img1286_cls0_0.jpg
#
# Renaming:
#   img1419_jpg.rf.2f3313cd0dc0345c327f0f9c728c26dd_cls0_0.jpg
# → img1419_cls0_0.jpg
#
# Renaming:
#   img1449_jpg.rf.9d2e11655e05025500d23cd1b0595d2c_cls0_0.jpg
# → img1449_cls0_0.jpg
#
# Renaming:
#   img1556_jpg.rf.dec76d5982d27ce06030ba9fad9ca3c6_cls0_0.jpg
# → img1556_cls0_0.jpg
#
# Renaming:
#   img1472_jpg.rf.fa0376213a1d33023f57fe172a1bba81_cls0_0.jpg
# → img1472_cls0_0.jpg
#
# Renaming:
#   img1380_jpg.rf.d4bfc21010e093f0c13bd0996982d7ed_cls0_0.jpg
# → img1380_cls0_0.jpg
#
# Renaming:
#   img1234_jpg.rf.594c2dbdbe2726f1d2d767436e87bec8_cls0_0.jpg
# → img1234_cls0_0.jpg
#
# Renaming:
#   img1386_jpg.rf.7009c7d2c203531619a73e0a86b4be52_cls0_0.jpg
# → img1386_cls0_0.jpg
#
# Renaming:
#   img1311_jpg.rf.666d4c978285f01d50264687b1562917_cls0_0.jpg
# → img1311_cls0_0.jpg
#
# Renaming:
#   img1058_jpg.rf.47e608619d6c89add758b9f70e85b9f5_cls0_0.jpg
# → img1058_cls0_0.jpg
#
# Renaming:
#   img1294_jpg.rf.a357c554ac3056f8b32f0d1f9c94751e_cls0_0.jpg
# → img1294_cls0_0.jpg
#
# Renaming:
#   img1298_jpg.rf.bdcd78709ee6273f80abb9b5376b818d_cls0_0.jpg
# → img1298_cls0_0.jpg
#
# Renaming:
#   img1152_jpg.rf.72a4f7facf9306b5c554beb0e01c4803_cls0_0.jpg
# → img1152_cls0_0.jpg
#
# Renaming:
#   img1520_jpg.rf.0f24929dc2a12adfea677be86f96c029_cls0_0.jpg
# → img1520_cls0_0.jpg
#
# Renaming:
#   img1365_jpg.rf.8fa314a747b2fbad9a90a11065446430_cls0_0.jpg
# → img1365_cls0_0.jpg
#
# Renaming:
#   img1622_jpg.rf.3a3d2a1de77a1ba14e904a6c07d4a404_cls0_0.jpg
# → img1622_cls0_0.jpg
#
# Renaming:
#   img1340_jpg.rf.440f59b48b55ba57a483d18743e35d8b_cls0_0.jpg
# → img1340_cls0_0.jpg
#
# Renaming:
#   img1433_jpg.rf.2db10951c38bffecc809132176f04518_cls0_0.jpg
# → img1433_cls0_0.jpg
#
# Renaming:
#   img1420_jpg.rf.0e2c2e5734957a809e7dfbc1e3b9cf07_cls0_0.jpg
# → img1420_cls0_0.jpg
#
# Renaming:
#   img1426_jpg.rf.79f2115b27967483ec99c9d16405599e_cls0_0.jpg
# → img1426_cls0_0.jpg
#
# Renaming:
#   img1284_jpg.rf.6e81fb2ce98261a8428d6de2e5501286_cls0_0.jpg
# → img1284_cls0_0.jpg
#
# Renaming:
#   img1514_jpg.rf.b085a1cdff3258719dcdf7112981befc_cls0_0.jpg
# → img1514_cls0_0.jpg
#
# Renaming:
#   img1525_jpg.rf.431e5806cc4133c33ec60ddde7be751d_cls0_0.jpg
# → img1525_cls0_0.jpg
#
# Renaming:
#   img1332_jpg.rf.3e95a746c43c9a689242199cc5814716_cls0_0.jpg
# → img1332_cls0_0.jpg
#
# Renaming:
#   img1631_jpg.rf.325da880ca5c1f9b2fea2082552d2421_cls0_0.jpg
# → img1631_cls0_0.jpg
#
# Renaming:
#   img1117_jpg.rf.3f348058585b52387d8acc9aa9f2db84_cls0_0.jpg
# → img1117_cls0_0.jpg
#
# Renaming:
#   img1293_jpg.rf.6f8a68d0e92723a10c72f7541d063974_cls0_0.jpg
# → img1293_cls0_0.jpg
#
# Renaming:
#   img1288_jpg.rf.b5cc7ef0b53d4ac7976fc3fd5e248ad1_cls0_0.jpg
# → img1288_cls0_0.jpg
#
# Renaming:
#   img1442_jpg.rf.e7b233f3a6568fe4e0df5a331f6c1ace_cls0_0.jpg
# → img1442_cls0_0.jpg
#
# Renaming:
#   img1534_jpg.rf.7e9b297e59fedf4a7f9ed0c00e9a7eca_cls0_0.jpg
# → img1534_cls0_0.jpg
#
# Renaming:
#   img1547_jpg.rf.09386ace610e9c01b1a445ab3310d1f8_cls0_0.jpg
# → img1547_cls0_0.jpg
#
# Renaming:
#   img1299_jpg.rf.7f5b3e46f8a333b450deddf42ac1f831_cls0_0.jpg
# → img1299_cls0_0.jpg
#
# Renaming:
#   img1307_jpg.rf.b5017bf2bece18d10f5ce6882a960bf9_cls0_0.jpg
# → img1307_cls0_0.jpg
#
# Renaming:
#   img1634_jpg.rf.d2acf5d1dda60da411b76f9821dd48c7_cls0_0.jpg
# → img1634_cls0_0.jpg
#
# Renaming:
#   img1281_jpg.rf.f8e8f86dbf2f03d75a0c46b846269e02_cls0_0.jpg
# → img1281_cls0_0.jpg
#
# Renaming:
#   img1319_jpg.rf.0f6c59c50d1b147f6c89de3e58304c88_cls0_0.jpg
# → img1319_cls0_0.jpg
#
# Renaming:
#   img1494_jpg.rf.354559cb33127dc5353814815685dc03_cls0_0.jpg
# → img1494_cls0_0.jpg
#
# Renaming:
#   img1368_jpg.rf.bba1c311adb174e63d881581bd3a9150_cls0_0.jpg
# → img1368_cls0_0.jpg
#
# Renaming:
#   img1428_jpg.rf.dbb3116709b6dc6f3d8492b206958cf8_cls0_0.jpg
# → img1428_cls0_0.jpg
#
# Renaming:
#   img1571_jpg.rf.31ae7b95bdfe4ea2b29ef8b2b420048c_cls0_0.jpg
# → img1571_cls0_0.jpg
#
# Renaming:
#   img1550_jpg.rf.e8a0032260f17f3035c9873c3459a283_cls0_0.jpg
# → img1550_cls0_0.jpg
#
# Renaming:
#   img1266_jpg.rf.430e9d47d4d12883e84f4206c5e412dc_cls0_0.jpg
# → img1266_cls0_0.jpg
#
# Renaming:
#   img1265_jpg.rf.1e4a9ec3426b14ef8e997b2791d23739_cls0_0.jpg
# → img1265_cls0_0.jpg
#
# Renaming:
#   img1301_jpg.rf.192122198538b71e7138635292e32404_cls0_0.jpg
# → img1301_cls0_0.jpg
#
# Renaming:
#   img1279_jpg.rf.651b1cca5c1eb16231be883c9e414afc_cls0_0.jpg
# → img1279_cls0_0.jpg
#
# Renaming:
#   img1543_jpg.rf.f293e40b141cc4b1bcc2100e96fb8ae0_cls0_0.jpg
# → img1543_cls0_0.jpg
#
# Renaming:
#   img1446_jpg.rf.7c0621cfb478dec06017f02456ce8a7f_cls0_0.jpg
# → img1446_cls0_0.jpg
#
# Renaming:
#   img1320_jpg.rf.3a33a66b19ddbcb127a0b105bb956cb8_cls0_0.jpg
# → img1320_cls0_0.jpg
#
# Renaming:
#   img1616_jpg.rf.de38bf50745ea029f69a78f33f551f99_cls0_0.jpg
# → img1616_cls0_0.jpg
#
# Renaming:
#   img1295_jpg.rf.fe65fe97ffae101ed169b10d4bcfd09f_cls0_0.jpg
# → img1295_cls0_0.jpg
#
# Renaming:
#   img1276_jpg.rf.9a9573c331603c952cd1ef6afcbd67f4_cls0_0.jpg
# → img1276_cls0_0.jpg
#
# Renaming:
#   img1625_jpg.rf.cf2f1972c5f00e23e33017b91efacc2d_cls0_0.jpg
# → img1625_cls0_0.jpg
#
# Renaming:
#   img1352_jpg.rf.9311481ede9f9d6feb3a3ca8b20b7535_cls0_0.jpg
# → img1352_cls0_0.jpg
#
# Renaming:
#   img1338_jpg.rf.ed21fc255a8bf04b547f652421e6a71c_cls0_0.jpg
# → img1338_cls0_0.jpg
#
# Renaming:
#   img1529_jpg.rf.69bb01fc5f73a5fc821354ba4bef763e_cls0_0.jpg
# → img1529_cls0_0.jpg
#
# Renaming:
#   img1558_jpg.rf.2e8760cef587b623e5c3992d81b3bc3f_cls0_0.jpg
# → img1558_cls0_0.jpg
#
# Renaming:
#   img1333_jpg.rf.d2a5dc9ea9ccf2da58eb6d5e815094c0_cls0_0.jpg
# → img1333_cls0_0.jpg
#
# Renaming:
#   img1600_jpg.rf.dfa369803b58225807b24f402d1d6c14_cls0_0.jpg
# → img1600_cls0_0.jpg
#
# Renaming:
#   img1452_jpg.rf.bfc7b7bd7b598749da75d26fcabb1dde_cls0_0.jpg
# → img1452_cls0_0.jpg
#
# Renaming:
#   img1436_jpg.rf.290357804362a799f7e2e8f29c8adf03_cls0_0.jpg
# → img1436_cls0_0.jpg

# %%
import os

def simplify_filenames(folder: str):
    for fname in os.listdir(folder):
        full_path = os.path.join(folder, fname)
        if not os.path.isfile(full_path):
            continue

        base, ext = os.path.splitext(fname)
        # take only the part before the first underscore
        new_base = base.split("_", 1)[0]
        new_name = new_base + ext
        new_path = os.path.join(folder, new_name)

        # if a file with the target name already exists, skip or overwrite
        if new_path != full_path:
            if os.path.exists(new_path):
                print(f"⚠️  {new_name} already exists, skipping rename of {fname}")
            else:
                print(f"Renaming: {fname} → {new_name}")
                os.rename(full_path, new_path)

if __name__ == "__main__":
    simplify_filenames("cropped_id_train_1")
# Out:
# Renaming: img1589_cls0_0.jpg → img1589.jpg
# Renaming: img1514_cls0_0.jpg → img1514.jpg
# Renaming: img1276_cls0_0.jpg → img1276.jpg
# Renaming: img1362_cls0_0.jpg → img1362.jpg
# Renaming: img1437_cls0_0.jpg → img1437.jpg
# Renaming: img1300_cls0_0.jpg → img1300.jpg
# Renaming: img1337_cls0_0.jpg → img1337.jpg
# Renaming: img1295_cls0_0.jpg → img1295.jpg
# Renaming: img1381_cls0_0.jpg → img1381.jpg
# Renaming: img1349_cls0_0.jpg → img1349.jpg
# Renaming: img1634_cls0_0.jpg → img1634.jpg
# Renaming: img1449_cls0_0.jpg → img1449.jpg
# Renaming: img1603_cls0_0.jpg → img1603.jpg
# Renaming: img1075_cls0_0.jpg → img1075.jpg
# Renaming: img1625_cls0_0.jpg → img1625.jpg
# Renaming: img1284_cls0_0.jpg → img1284.jpg
# Renaming: img1326_cls0_0.jpg → img1326.jpg
# Renaming: img1311_cls0_0.jpg → img1311.jpg
# Renaming: img1550_cls0_0.jpg → img1550.jpg
# Renaming: img1567_cls0_0.jpg → img1567.jpg
# Renaming: img1426_cls0_0.jpg → img1426.jpg
# Renaming: img1344_cls0_0.jpg → img1344.jpg
# Renaming: img1532_cls0_0.jpg → img1532.jpg
# Renaming: img1298_cls0_0.jpg → img1298.jpg
# Renaming: img1281_cls0_0.jpg → img1281.jpg
# Renaming: img1581_cls0_0.jpg → img1581.jpg
# Renaming: img1620_cls0_0.jpg → img1620.jpg
# Renaming: img1308_cls0_0.jpg → img1308.jpg
# Renaming: img1617_cls0_0.jpg → img1617.jpg
# Renaming: img1117_cls0_0.jpg → img1117.jpg
# Renaming: img1408_cls0_0.jpg → img1408.jpg
# Renaming: img1314_cls0_0.jpg → img1314.jpg
# Renaming: img1323_cls0_0.jpg → img1323.jpg
# Renaming: img1441_cls0_0.jpg → img1441.jpg
# Renaming: img1537_cls0_0.jpg → img1537.jpg
# Renaming: img1432_cls0_0.jpg → img1432.jpg
# Renaming: img1350_cls0_0.jpg → img1350.jpg
# Renaming: img1405_cls0_0.jpg → img1405.jpg
# Renaming: img1526_cls0_0.jpg → img1526.jpg
# Renaming: img1332_cls0_0.jpg → img1332.jpg
# Renaming: img1573_cls0_0.jpg → img1573.jpg
# Renaming: img1419_cls0_0.jpg → img1419.jpg
# Renaming: img1558_cls0_0.jpg → img1558.jpg
# Renaming: img1319_cls0_0.jpg → img1319.jpg
# Renaming: img1631_cls0_0.jpg → img1631.jpg
# Renaming: img1590_cls0_0.jpg → img1590.jpg
# Renaming: img1290_cls0_0.jpg → img1290.jpg
# Renaming: img1297_cls0_0.jpg → img1297.jpg
# Renaming: img1268_cls0_0.jpg → img1268.jpg
# Renaming: img1601_cls0_0.jpg → img1601.jpg
# Renaming: img1329_cls0_0.jpg → img1329.jpg
# Renaming: img1357_cls0_0.jpg → img1357.jpg
# Renaming: img1435_cls0_0.jpg → img1435.jpg
# Renaming: img1402_cls0_0.jpg → img1402.jpg
# Renaming: img1360_cls0_0.jpg → img1360.jpg
# Renaming: img1543_cls0_0.jpg → img1543.jpg
# Renaming: img1302_cls0_0.jpg → img1302.jpg
# Renaming: img1313_cls0_0.jpg → img1313.jpg
# Renaming: img1446_cls0_0.jpg → img1446.jpg
# Renaming: img1324_cls0_0.jpg → img1324.jpg
# Renaming: img1552_cls0_0.jpg → img1552.jpg
# Renaming: img1371_cls0_0.jpg → img1371.jpg
# Renaming: img1346_cls0_0.jpg → img1346.jpg
# Renaming: img1424_cls0_0.jpg → img1424.jpg
# Renaming: img1265_cls0_0.jpg → img1265.jpg
# Renaming: img1627_cls0_0.jpg → img1627.jpg
# Renaming: img1338_cls0_0.jpg → img1338.jpg
# Renaming: img1610_cls0_0.jpg → img1610.jpg
# Renaming: img1279_cls0_0.jpg → img1279.jpg
# Renaming: img1438_cls0_0.jpg → img1438.jpg
# Renaming: img1286_cls0_0.jpg → img1286.jpg
# Renaming: img1235_cls0_0.jpg → img1235.jpg
# Renaming: img1560_cls0_0.jpg → img1560.jpg
# Renaming: img1443_cls0_0.jpg → img1443.jpg
# Renaming: img1321_cls0_0.jpg → img1321.jpg
# Renaming: img1316_cls0_0.jpg → img1316.jpg
# Renaming: img1283_cls0_0.jpg → img1283.jpg
# Renaming: img1622_cls0_0.jpg → img1622.jpg
# Renaming: img1368_cls0_0.jpg → img1368.jpg
# Renaming: img1529_cls0_0.jpg → img1529.jpg
# Renaming: img1036_cls0_0.jpg → img1036.jpg
# Renaming: img1386_cls0_0.jpg → img1386.jpg
# Renaming: img1292_cls0_0.jpg → img1292.jpg
# Renaming: img1365_cls0_0.jpg → img1365.jpg
# Renaming: img1352_cls0_0.jpg → img1352.jpg
# Renaming: img1430_cls0_0.jpg → img1430.jpg
# Renaming: img1271_cls0_0.jpg → img1271.jpg
# Renaming: img1307_cls0_0.jpg → img1307.jpg
# Renaming: img1452_cls0_0.jpg → img1452.jpg
# Renaming: img1330_cls0_0.jpg → img1330.jpg
# Renaming: img1571_cls0_0.jpg → img1571.jpg
# Renaming: img1616_cls0_0.jpg → img1616.jpg
# Renaming: img1309_cls0_0.jpg → img1309.jpg
# Renaming: img973_cls0_0.jpg → img973.jpg
# Renaming: img1548_cls0_0.jpg → img1548.jpg
# Renaming: img1035_cls0_0.jpg → img1035.jpg
# Renaming: img1280_cls0_0.jpg → img1280.jpg
# Renaming: img1494_cls0_0.jpg → img1494.jpg
# Renaming: img1554_cls0_0.jpg → img1554.jpg
# Renaming: img1440_cls0_0.jpg → img1440.jpg
# Renaming: img1322_cls0_0.jpg → img1322.jpg
# Renaming: img1377_cls0_0.jpg → img1377.jpg
# Renaming: img1340_cls0_0.jpg → img1340.jpg
# Renaming: img1488_cls0_0.jpg → img1488.jpg
# Renaming: img1351_cls0_0.jpg → img1351.jpg
# Renaming: img1433_cls0_0.jpg → img1433.jpg
# Renaming: img1404_cls0_0.jpg → img1404.jpg
# Renaming: img1366_cls0_0.jpg → img1366.jpg
# Renaming: img1038_cls0_0.jpg → img1038.jpg
# Renaming: img1451_cls0_0.jpg → img1451.jpg
# Renaming: img1333_cls0_0.jpg → img1333.jpg
# Renaming: img1545_cls0_0.jpg → img1545.jpg
# Renaming: img1485_cls0_0.jpg → img1485.jpg
# Renaming: img1318_cls0_0.jpg → img1318.jpg
# Renaming: img1152_cls0_0.jpg → img1152.jpg
# Renaming: img1277_cls0_0.jpg → img1277.jpg
# Renaming: img1363_cls0_0.jpg → img1363.jpg
# Renaming: img1436_cls0_0.jpg → img1436.jpg
# Renaming: img1301_cls0_0.jpg → img1301.jpg
# Renaming: img1629_cls0_0.jpg → img1629.jpg
# Renaming: img1336_cls0_0.jpg → img1336.jpg
# Renaming: img1288_cls0_0.jpg → img1288.jpg
# Renaming: img1348_cls0_0.jpg → img1348.jpg
# Renaming: img1448_cls0_0.jpg → img1448.jpg
# Renaming: img1294_cls0_0.jpg → img1294.jpg
# Renaming: img1380_cls0_0.jpg → img1380.jpg
# Renaming: img1491_cls0_0.jpg → img1491.jpg
# Renaming: img1171_cls0_0.jpg → img1171.jpg
# Renaming: img1359_cls0_0.jpg → img1359.jpg
# Renaming: img1299_cls0_0.jpg → img1299.jpg
# Renaming: img1445_cls0_0.jpg → img1445.jpg
# Renaming: img1310_cls0_0.jpg → img1310.jpg
# Renaming: img1472_cls0_0.jpg → img1472.jpg
# Renaming: img1233_cls0_0.jpg → img1233.jpg
# Renaming: img1427_cls0_0.jpg → img1427.jpg
# Renaming: img1266_cls0_0.jpg → img1266.jpg
# Renaming: img1556_cls0_0.jpg → img1556.jpg
# Renaming: img1234_cls0_0.jpg → img1234.jpg
# Renaming: img1561_cls0_0.jpg → img1561.jpg
# Renaming: img1320_cls0_0.jpg → img1320.jpg
# Renaming: img1442_cls0_0.jpg → img1442.jpg
# Renaming: img1608_cls0_0.jpg → img1608.jpg
# Renaming: img1317_cls0_0.jpg → img1317.jpg
# Renaming: img1534_cls0_0.jpg → img1534.jpg
# Renaming: img1420_cls0_0.jpg → img1420.jpg
# Renaming: img1342_cls0_0.jpg → img1342.jpg
# Renaming: img1614_cls0_0.jpg → img1614.jpg
# Renaming: img1528_cls0_0.jpg → img1528.jpg
# Renaming: img1282_cls0_0.jpg → img1282.jpg
# Renaming: img1593_cls0_0.jpg → img1593.jpg
# Renaming: img1293_cls0_0.jpg → img1293.jpg
# Renaming: img1539_cls0_0.jpg → img1539.jpg
# Renaming: img1478_cls0_0.jpg → img1478.jpg
# Renaming: img1605_cls0_0.jpg → img1605.jpg
# Renaming: img1431_cls0_0.jpg → img1431.jpg
# Renaming: img1353_cls0_0.jpg → img1353.jpg
# Renaming: img1512_cls0_0.jpg → img1512.jpg
# Renaming: img1270_cls0_0.jpg → img1270.jpg
# Renaming: img1525_cls0_0.jpg → img1525.jpg
# Renaming: img1306_cls0_0.jpg → img1306.jpg
# Renaming: img1331_cls0_0.jpg → img1331.jpg
# Renaming: img1453_cls0_0.jpg → img1453.jpg
# Renaming: img1547_cls0_0.jpg → img1547.jpg
# Renaming: img1058_cls0_0.jpg → img1058.jpg
# Renaming: img1428_cls0_0.jpg → img1428.jpg
# Renaming: img1269_cls0_0.jpg → img1269.jpg
# Renaming: img1600_cls0_0.jpg → img1600.jpg
# Renaming: img1328_cls0_0.jpg → img1328.jpg
# Renaming: img1520_cls0_0.jpg → img1520.jpg
# Renaming: img1275_cls0_0.jpg → img1275.jpg
# Renaming: img1434_cls0_0.jpg → img1434.jpg
# Renaming: img1361_cls0_0.jpg → img1361.jpg
# Renaming: img1334_cls0_0.jpg → img1334.jpg
# Renaming: img1303_cls0_0.jpg → img1303.jpg
# Renaming: img1325_cls0_0.jpg → img1325.jpg
# Renaming: img1447_cls0_0.jpg → img1447.jpg
# Renaming: img1564_cls0_0.jpg → img1564.jpg
# Renaming: img1425_cls0_0.jpg → img1425.jpg
# Renaming: img1347_cls0_0.jpg → img1347.jpg
# Renaming: img1287_cls0_0.jpg → img1287.jpg
# Renaming: img1587_cls0_0.jpg → img1587.jpg
# Renaming: img1578_cls0_0.jpg → img1578.jpg
# Renaming: img1339_cls0_0.jpg → img1339.jpg
# Renaming: img1278_cls0_0.jpg → img1278.jpg
# Renaming: img1439_cls0_0.jpg → img1439.jpg
